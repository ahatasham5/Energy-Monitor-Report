# %% [markdown]
# <a href="https://colab.research.google.com/github/ahatasham5/Energy-Monitor-Report/blob/main/Graph-of-Energy-Monitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "/content/Short-Notesrevised.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#            Date      Time   Watt    Ampere        Workload  Voltage
# 0      9/4/2024  15:22:33   53.1  0.241364          normal      220
# 1      9/4/2024  15:24:27   78.5  0.356818          normal      220
# 2      9/4/2024  15:26:54   89.7  0.407727          normal      220
# 3      9/4/2024  15:27:34   74.0  0.336364          normal      220
# 4      9/4/2024  15:36:18  149.0  0.677273  rdr2 benchmark      220
# ..          ...       ...    ...       ...             ...      ...
# 97   15/04/2024  12:01:27   54.3  0.246818           video      220
# 98   15/04/2024  12:11:16   51.6  0.234545           video      220
# 99   15/04/2024  12:22:04   58.1  0.264091           video      220
# 100  15/04/2024  12:32:12   57.4  0.260909           video      220
# 101  15/04/2024  12:42:12   55.7  0.253182           video      220
#
# [102 rows x 6 columns]

# %%
plt.figure(figsize=(15,6))
plt.hist(df['Workload'], weights=df['Watt'])
plt.xlabel('Workload')
plt.ylabel('Watt')
plt.title('Histogram of Watt by Workload')
plt.grid(True)
